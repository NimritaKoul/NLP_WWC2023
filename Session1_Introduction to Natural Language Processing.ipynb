# %% [markdown]
# # Natural Language Processing using Python
# ####  This  4 hour workshop will introduce the audience to the field of Natural Language Processing,  we will cover the fundamental tasks in NLP and walk through the Python code for some of the important steps in an NLP project.
#
# #### Author: Dr. Nimrita Koul, Associate Professor, Machine Learning
# #### Who this talk is suitable for: Data analysts, students and anyone interested in using Natural Language Processing
# #### Prerequisites: Python Programming, basic familiarity with concepts in data science and machine learning
# #### Duration: 4 Hours
# #### Time:  Starting 9th March 2023, Every Thursday,  8.00 pm to 9.00 pm Indian Standard Time
# #### Github Link of this Jupyter Notebook:
#
# ### Contents:
#
# #### Session 1:
# 1. Introduction to Natural Language Processing, components, task, applications.
# 2. Python Tools and Libraries for NLP - with focus on NLTK and SpaCy
#
# #### Session 2:
# 1. Text Preprocessing - Cleaning, normalization - tokenization, stopword removal, case conversion, stemming, lemmatization, POS tagging, Named Entity Recognition
# 2. Text Representation - Bag of word models, TF-IDF, Word Embeddings
#
# #### Session 3:
# 1. Text Classification - Text classification models Naive Bayes, Decision Tree, RNN
# 2. Transformers
#
# #### Session 4 :  Case Study
# 1. Sentiment Analysis
# 2. Chatbot

# %% [markdown]
# ## References
#
# 1. https://www.ibm.com/in-en/topics/natural-language-processing
#
# 2. https://github.com/adashofdata/nlp-in-python-tutorial/blob/master/1-Data-Cleaning.ipynb
#
# 3. https://github.com/PacktPublishing/Hands-On-Natural-Language-Processing-with-Python/blob/master/Chapter02/01_example.ipynb
#
# 4. https://www.deeplearning.ai/resources/natural-language-processing/
#
# 5. https://python-course.eu/machine-learning/natural-language-processing-with-python.php
#
# 6. https://web.stanford.edu/~jurafsky/slp3/
#
# 7. https://web.stanford.edu/class/archive/cs/cs224n/cs224n.1184/syllabus.html
#
# 8. https://github.com/nlpbook/nlpbook
#
# 9. https://proxet.com/blog/spacy-vs-nltk-natural-language-processing-nlp-python-libraries/
#
# 10. https://www.youtube.com/watch?v=-lnHHWRCDGk
# 11.https://notebook.community/harishkrao/DSE200x/Week-8-NLP-Databases/Natural%20Language%20Processing%20of%20Movie%20Reviews%20using%20nltk%20
#
# 12. https://www.topbots.com/leading-nlp-language-models-2020/
# 13. https://www.lexalytics.com/blog/machine-learning-natural-language-processing/
# 14. https://www.nltk.org/book
# 15. https://course.spacy.io/en/
# 16. https://www.analyticsvidhya.com/blog/2021/07/nltk-a-beginners-hands-on-guide-to-natural-language-processing/
# 17. https://web.stanford.edu/~gentzkow/research/text-as-data.pdf
# 18. https://deepnote.com/workspace/first-deepnote-workspace-4765-9d94-7922dbf9-d284-4449-8656-b8b45c1a0256/project/cmuDSCWorkshopNotebooks-63762062-2e74-4323-b193-bd9bb7f9589d/notebook/.ipynb_checkpoints%2FpracticalNLPWorkshop-checkpoint-1644502a18974aec8a215967f75d14a7
# 19. https://github.com/n-kostadinov/sentiment-analysis
# 20. https://notebook.community/DryingPole/sentiment/notebooks/Final%20Project%20Process%20Book
# 21. https://nbviewer.org/url/norvig.com/ipython/How%20to%20Do%20Things%20with%20Words.ipynb
# 22. https://www.cs.bgu.ac.il/~elhadad/nlp21.html
# 23. https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
# 24. https://spacy.io/usage/spacy-101
# 25. https://paperswithcode.com/task/language-modelling
# 26. https://lena-voita.github.io/nlp_course/language_modeling.html

# %% [markdown]
# ## Session 1 : 9 March 2023
#
# ### On the Agenda:
#
# 1. Introduction to Natural Language Processing
# 2. Getting started with Python Libraries NLTK and SpaCy
#
# # Natural Language Processing (NLP)
#
# #### A Natural Language is a language like Hindi, English, German, French, Spanish etc. that is used by "Humans" to communicate among themselves. Most of the information about human communications is unstructured.
#
# #### Text in human languages is the most abundant form of data available on the Web.
#
#
# <img src = 'big-data-sources.png'>
# <center>Source: https://www.smartdatacollective.com/big-data-20-free-big-data-sources-everyone-should-know/</center>
#
# #### Sources of this text include (Source:https://pitt.libguides.com/textmining/sources)
#
# - Library databases
# - Social media
# - Open sources
# - Web scraping
# - Language corpora
# - Transcription of audio/video data
#
# #### The information encoded in text is an important complement to structured data. Recently we have seen a great surge in the applications that use text as input and produce output in text. Such applications are used in the domains of governance, finance, social media, customer engagement, politics, health care, entertainment.
#
# #### Application of AI methods to this data can lead to wonderful insights and tools.  But the text data first needs to be pre-processed to convert it into formats that can be fed to a machine learning model.
#
# ## Natural Language Processing (NLP) is a branch of AI that aims at building computer systems that can understand natural language and respond in a natural language.
#
# - <b>Human language is filled with ambiguities</b> To "understand" written or spoken text in a natural language means to recognize the meaning, the intent and the sentiment of it.NLP uses statistical models, machine learning, deep learning to understand text.
#
# <img src = 'ambiguities1.png' width=800 height = 800>
# <center>Source: https://fidelandrada-writing.medium.com/ambiguity-f14fc53b4721</center>
#
#
# <img src = 'ambiguity3a.jpg' width = 400 height = 400>
# <center>Source:https://www.pinterest.com/pin/siri-call-an-ambulance--13088655139792945/</center>
#
# #### These ambiguities in natural language make task of understanding natural language very hard. Several NLP tasks break down human text and voice data in ways that help the computer make sense of it.
#
# ### Understanding natural languages involves tasks like
#
# <img src = 'postagsnltk.png'>
# <center>Source: https://www.analyticsvidhya.com</center>
#
#
# 1. <b>Speech recognition </b>or called speech-to-text conversion is the task of reliably converting voice data into text data. Different speeds, punctuation, emphasis, intonation, accents, incorrect grammar slurrying words together makes speech recognition especially challenging.
#
# 2. <b>Part of speech tagging </b>or grammatical tagging, Identifying grammatical class (Part of speech) of the word e.g., nouns, verbs etc. based on its use and context. E.g., to correctly tag  ‘make’ as a verb in ‘I can make a paper plane,’ and as a noun in ‘What make of car do you own?’
#
# 3. <b>Identifying relationships</b> among nouns and verbs. (Who is doing what to whom?)
#
# 3. <b>Word sense disambiguation</b> is the selection of the meaning of a word with multiple meanings through a process of semantic analysis that determine the word that makes the most sense in the given context. For example, word sense disambiguation helps distinguish the meaning of the verb 'make' in ‘make the grade’ (achieve) vs. ‘make a bet’ (place).
#
# 4. <b>Named entity recognition </b>, or NEM, identifies words or phrases as useful entities. Identifying real world Entities. (Names of people, countries, companies)
#
# 5. <b>Co-reference resolution </b>is the task of identifying if and when two words refer to the same entity. The most common example is determining the person or object to which a certain pronoun refers (e.g., ‘she’ = ‘Mary’),  but it can also involve identifying a metaphor or an idiom in the text  (e.g., an instance in which 'bear' isn't an animal but a large hairy person).
#
# 6. <b>Sentiment analysis</b> attempts to extract subjective qualities—attitudes, emotions, sarcasm, confusion, suspicion—from text.
#
# 7. <b>Natural language generation </b>is the task of putting structured information into human language.
#
#
# ### NLP use cases
#
# 1.<b> Spam detection:</b> It applied NLP's text classification techniques to identify words indicative of spam, phishing behaviour. These may include overuse of financial terms, characteristic bad grammar, threatening language, inappropriate urgency, misspelled company names, and more.
#
# 2.<b> Machine translation:</b> Effective machine translation systems accurately capture the meaning and tone of input language and translate it to another language with same meaning and tone.
#
# 3.<b>Smart Virtual agents and chatbots: </b>These agents, such as Apple's Siri and Amazon's Alexa, use speech recognition and natural language generation technologies to recognize patterns in voice commands and generate response. They also recognize contextual clues about human requests. Question-answering systems have the ability to respond to our questions - anticipated or unanticipated.
#
# 4.<b>Social media sentiment analysis:</b> For businesses, it is very important to know the pulse of the customers. NLP helps discover hidden insights, intents, attitudes, emotions from data customers put of social media forums, shopping sights.
#
# 5.<b>Text summarization:</b> This involves use of NLP techniques of semantic reasoning and natural language generation to parse huge volumes of digital text and create summaries and synopses for users, indexes, research databases. Document Summarization
#
# 6.<b>Recognizing Textual Entailment:</b> Textual entailment (TE), also known as Natural Language Inference (NLI), is a directional relation between text fragments. The relation holds whenever the truth of one text fragment follows from another text.
#
# 6.<b>Generating Captions for Images.</b>

# %% [markdown]
# ## Machine Learning Models for NLP
#
# #### Deep Learning Architectures for NLP
#
# 1. RNN
# 2. CNN
# 3. LSTM
# 4. Transformers
#
# #### Prominent Deep Learning Models for NLP
# 1. BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
#
# 2. GPT2: Language Models Are Unsupervised Multitask Learners
#
# 3. XLNet: Generalized Autoregressive Pretraining for Language Understanding
#
# 4. RoBERTa: A Robustly Optimized BERT Pretraining Approach
#
# 5. ALBERT: A Lite BERT for Self-supervised Learning of Language Representations
#
# 6. T5: Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer
#
# 7. GPT3: Language Models Are Few-Shot Learners
#
# 8. ELECTRA: Pre-training Text Encoders as Discriminators Rather Than Generators
#
# 9. DeBERTa: Decoding-enhanced BERT with Disentangled Attention
#
# 10. PaLM: Scaling Language Modeling with Pathways
#
# #### Python has some very powerful libraries for NLP
#
# 1. NLTK - Natural Language Toolkit - NLTK is a powerful, open source library for research and development in NLP. It has more than 50 text corpora and lexical resources built into it. It supports text tokenization, part of speech tagging, stemming, lemmatization,named entity extraction, segmentation, classification, semantic reasoning.
#
# 2. SpaCY - SpaCy is also an open source python library for production level use for building real world projects. It has builtin support for multi-trained transformers like BERT and pre-trained NLP pipelines for more than 17 languages. It is very fast and provides following functionality - tokenization in more than 49 languages, part of speech tagging, segmentation, lemmatization, named entity recognition, text classification.
#
# 3. TextBlob - TextBlob is an open-source library built on top of NLTK. It provides an easy interface and supports tasks like sentiment analysis, phrase extraction, parsing, Part-of-speech tagging, N-grams,Spelling correction, Tokenization
# Classification, Noun phrase extraction.
#
# 4. Gensim - GenSim supports algorithms like Hierarhical Dirichlet Process (HDP), Random Projections, latent Dirichlet Allocation (LDA), latent Semantic Analysis or word2vec deep learning. It is very fast and optimizes memory useage.
#
# 5. PolyGlot - PolyGlot supports many languages and is built on SpaCy and NumPy libraries. It supports tokenization in 165 languages, language detection for 196 languages, named entity recognition, POS tagging, sentiment analysis, word embeddings for 137 languages, morphological analysis, transliteration in 69 languages.
#
# 6. sklearn - Standard Machine Learning library in Python
#
# We will look at the functionality of NLTK and SpaCy in some detail.

# %% [markdown]
# ## Natural Language Toolkit (NLTK)
#
# #### Download and Install
# using pip:
# <code> pip install nltk</code>
#
# For Ananconda using conda:
# <code> conda install nltk</code>
#
# #### NLTK Data Download
# NLTK comes with many corpora, toy grammars, trained models, etc. (https://www.nltk.org/nltk_data/)
# After installing NLTK, we should install data using NLTK's data downloader:
#
# <code>
# import nltk
# nltk.download()
# </code>
#
# A new window should open, showing the NLTK Downloader. You can choose which corpora you wish to download. You can also download all of them.
#
# ### Language processing tasks and corresponding NLTK modules with examples of functionality.
#
# |Language processing task	|NLTK modules	|Functionality|
# |-|-|-|
# |Accessing corpora|	corpus|	standardized interfaces to corpora and lexicons|
# |String processing|	tokenize, stem	| tokenizers, sentence tokenizers, stemmers|
# |Collocation discovery|	collocations|	t-test, chi-squared, point-wise mutual information|
# |Part-of-speech tagging|	tag	| n-gram, backoff, Brill, HMM, TnT|
# |Machine learning|	classify, cluster, tbl	|decision tree, maximum entropy, naive Bayes, EM, k-means|
# |Chunking|	chunk|	regular expression, n-gram, named-entity|
# |Parsing|	parse, ccg|	chart, feature-based, unification, probabilistic, dependency|
# |Semantic interpretation|	sem, inference|	lambda calculus, first-order logic, model checking|
# |Evaluation metrics|	metrics	|precision, recall, agreement coefficients|
# |Probability and estimation|	probability	|frequency distributions, smoothed probability distributions|
# |Applications|	app, chat	|graphical concordancer, parsers, WordNet browser, chatbots|
# |Linguistic fieldwork|	toolbox|	manipulate data in SIL Toolbox format|
#
# We will see a demonstration of following functionality of NLTK here:
# 1. Accessing Corpora
# 2. Tokenization
# 3. Stemming
# 4. Lemmatization
# 5. POS Tagging

# %% [markdown]
# ### NLTK includes a diverse set of corpora which can be read using the nltk.corpus package. Each corpus is accessed by means of a “corpus reader” object from nltk.corpus:

# %%
# Builtin corpora in NLTK (https://www.nltk.org/howto/corpus.html)
import nltk.corpus
from nltk.corpus import brown
brown.fileids()
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44',
#  'cb01',
#  'cb02',
#  'cb03',
#  'cb04',
#  'cb05',
#  'cb06',
#  'cb07',
#  'cb08',
#  'cb09',
#  'cb10',
#  'cb11',
#  'cb12',
#  'cb13',
#  'cb14',
#  'cb15',
#  'cb16',
#  'cb17',
#  'cb18',
#  'cb19',
#  'cb20',
#  'cb21',
#  'cb22',
#  'cb23',
#  'cb24',
#  'cb25',
#  'cb26',
#  'cb27',
#  'cc01',
#  'cc02',
#  'cc03',
#  'cc04',
#  'cc05',
#  'cc06',
#  'cc07',
#  'cc08',
#  'cc09',
#  'cc10',
#  'cc11',
#  'cc12',
#  'cc13',
#  'cc14',
#  'cc15',
#  'cc16',
#  'cc17',
#  'cd01',
#  'cd02',
# ...

# %% [markdown]
# Most corpora consist of a set of files, each containing a document (or other pieces of text). A list of identifiers for these files is accessed via the fileids() method of the corpus reader

# %%
nltk.corpus.treebank.fileids()
# Out:
# ['wsj_0001.mrg',
#  'wsj_0002.mrg',
#  'wsj_0003.mrg',
#  'wsj_0004.mrg',
#  'wsj_0005.mrg',
#  'wsj_0006.mrg',
#  'wsj_0007.mrg',
#  'wsj_0008.mrg',
#  'wsj_0009.mrg',
#  'wsj_0010.mrg',
#  'wsj_0011.mrg',
#  'wsj_0012.mrg',
#  'wsj_0013.mrg',
#  'wsj_0014.mrg',
#  'wsj_0015.mrg',
#  'wsj_0016.mrg',
#  'wsj_0017.mrg',
#  'wsj_0018.mrg',
#  'wsj_0019.mrg',
#  'wsj_0020.mrg',
#  'wsj_0021.mrg',
#  'wsj_0022.mrg',
#  'wsj_0023.mrg',
#  'wsj_0024.mrg',
#  'wsj_0025.mrg',
#  'wsj_0026.mrg',
#  'wsj_0027.mrg',
#  'wsj_0028.mrg',
#  'wsj_0029.mrg',
#  'wsj_0030.mrg',
#  'wsj_0031.mrg',
#  'wsj_0032.mrg',
#  'wsj_0033.mrg',
#  'wsj_0034.mrg',
#  'wsj_0035.mrg',
#  'wsj_0036.mrg',
#  'wsj_0037.mrg',
#  'wsj_0038.mrg',
#  'wsj_0039.mrg',
#  'wsj_0040.mrg',
#  'wsj_0041.mrg',
#  'wsj_0042.mrg',
#  'wsj_0043.mrg',
#  'wsj_0044.mrg',
#  'wsj_0045.mrg',
#  'wsj_0046.mrg',
#  'wsj_0047.mrg',
#  'wsj_0048.mrg',
#  'wsj_0049.mrg',
#  'wsj_0050.mrg',
#  'wsj_0051.mrg',
#  'wsj_0052.mrg',
# ...

# %% [markdown]
# Each corpus reader provides a variety of methods to read data from the corpus, depending on the format of the corpus. For example, plaintext corpora support methods to read the corpus as raw text, a list of words, a list of sentences, or a list of paragraphs.

# %%
from nltk.corpus import inaugural
inaugural.raw('1789-Washington.txt')
# Out:
# 'Fellow-Citizens of the Senate and of the House of Representatives:\n\nAmong the vicissitudes incident to life no event could have filled me with greater anxieties than that of which the notification was transmitted by your order, and received on the 14th day of the present month. On the one hand, I was summoned by my Country, whose voice I can never hear but with veneration and love, from a retreat which I had chosen with the fondest predilection, and, in my flattering hopes, with an immutable decision, as the asylum of my declining years -- a retreat which was rendered every day more necessary as well as more dear to me by the addition of habit to inclination, and of frequent interruptions in my health to the gradual waste committed on it by time. On the other hand, the magnitude and difficulty of the trust to which the voice of my country called me, being sufficient to awaken in the wisest and most experienced of her citizens a distrustful scrutiny into his qualifications, could n
# ...

# %%
inaugural.words('1789-Washington.txt')
# Out:
# ['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', ...]

# %%
inaugural.sents('1789-Washington.txt')
# Out:
# [['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House', 'of', 'Representatives', ':'], ['Among', 'the', 'vicissitudes', 'incident', 'to', 'life', 'no', 'event', 'could', 'have', 'filled', 'me', 'with', 'greater', 'anxieties', 'than', 'that', 'of', 'which', 'the', 'notification', 'was', 'transmitted', 'by', 'your', 'order', ',', 'and', 'received', 'on', 'the', '14th', 'day', 'of', 'the', 'present', 'month', '.'], ...]

# %%
inaugural.paras('1789-Washington.txt')
# Out:
# [[['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'of', 'the', 'House', 'of', 'Representatives', ':']], [['Among', 'the', 'vicissitudes', 'incident', 'to', 'life', 'no', 'event', 'could', 'have', 'filled', 'me', 'with', 'greater', 'anxieties', 'than', 'that', 'of', 'which', 'the', 'notification', 'was', 'transmitted', 'by', 'your', 'order', ',', 'and', 'received', 'on', 'the', '14th', 'day', 'of', 'the', 'present', 'month', '.'], ['On', 'the', 'one', 'hand', ',', 'I', 'was', 'summoned', 'by', 'my', 'Country', ',', 'whose', 'voice', 'I', 'can', 'never', 'hear', 'but', 'with', 'veneration', 'and', 'love', ',', 'from', 'a', 'retreat', 'which', 'I', 'had', 'chosen', 'with', 'the', 'fondest', 'predilection', ',', 'and', ',', 'in', 'my', 'flattering', 'hopes', ',', 'with', 'an', 'immutable', 'decision', ',', 'as', 'the', 'asylum', 'of', 'my', 'declining', 'years', '--', 'a', 'retreat', 'which', 'was', 'rendered', 'every', 'day', 'more', 'necessary', 'as', 'well', 'as', 'more', 'd
# ...

# %%
from nltk.corpus import indian
print(indian.words()) 
print(indian.tagged_words())
# Out:
# ['মহিষের', 'সন্তান', ':', 'তোড়া', 'উপজাতি', '৷', ...]
# [('মহিষের', 'NN'), ('সন্তান', 'NN'), (':', 'SYM'), ...]

# %%
print(brown.tagged_sents(tagset='universal'))
# Out:
# [[('The', 'DET'), ('Fulton', 'NOUN'), ('County', 'NOUN'), ('Grand', 'ADJ'), ('Jury', 'NOUN'), ('said', 'VERB'), ('Friday', 'NOUN'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ("Atlanta's", 'NOUN'), ('recent', 'ADJ'), ('primary', 'NOUN'), ('election', 'NOUN'), ('produced', 'VERB'), ('``', '.'), ('no', 'DET'), ('evidence', 'NOUN'), ("''", '.'), ('that', 'ADP'), ('any', 'DET'), ('irregularities', 'NOUN'), ('took', 'VERB'), ('place', 'NOUN'), ('.', '.')], [('The', 'DET'), ('jury', 'NOUN'), ('further', 'ADV'), ('said', 'VERB'), ('in', 'ADP'), ('term-end', 'NOUN'), ('presentments', 'NOUN'), ('that', 'ADP'), ('the', 'DET'), ('City', 'NOUN'), ('Executive', 'ADJ'), ('Committee', 'NOUN'), (',', '.'), ('which', 'DET'), ('had', 'VERB'), ('over-all', 'ADJ'), ('charge', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('election', 'NOUN'), (',', '.'), ('``', '.'), ('deserves', 'VERB'), ('the', 'DET'), ('praise', 'NOUN'), ('and', 'CONJ'), ('thanks', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Ci
# ...

# %% [markdown]
# #### Word Lists and Lexicons
# The NLTK data package also includes a number of lexicons and word lists. These are accessed just like text corpora. The following examples illustrate the use of the wordlist corpora:

# %%
from nltk.corpus import words
words.fileids()
# Out:
# ['en', 'en-basic']

# %%
print(words.words()[:100])
print(words.raw()[:100])
# Out:
# ['A', 'a', 'aa', 'aal', 'aalii', 'aam', 'Aani', 'aardvark', 'aardwolf', 'Aaron', 'Aaronic', 'Aaronical', 'Aaronite', 'Aaronitic', 'Aaru', 'Ab', 'aba', 'Ababdeh', 'Ababua', 'abac', 'abaca', 'abacate', 'abacay', 'abacinate', 'abacination', 'abaciscus', 'abacist', 'aback', 'abactinal', 'abactinally', 'abaction', 'abactor', 'abaculus', 'abacus', 'Abadite', 'abaff', 'abaft', 'abaisance', 'abaiser', 'abaissed', 'abalienate', 'abalienation', 'abalone', 'Abama', 'abampere', 'abandon', 'abandonable', 'abandoned', 'abandonedly', 'abandonee', 'abandoner', 'abandonment', 'Abanic', 'Abantes', 'abaptiston', 'Abarambo', 'Abaris', 'abarthrosis', 'abarticular', 'abarticulation', 'abas', 'abase', 'abased', 'abasedly', 'abasedness', 'abasement', 'abaser', 'Abasgi', 'abash', 'abashed', 'abashedly', 'abashedness', 'abashless', 'abashlessly', 'abashment', 'abasia', 'abasic', 'abask', 'Abassin', 'abastardize', 'abatable', 'abate', 'abatement', 'abater', 'abatis', 'abatised', 'abaton', 'abator', 'abattoir',
# ...

# %%
#### Stopwords : Words that add little or nothing to the meaning of the text.

# %%
from nltk.corpus import stopwords 
stopwords.fileids()
# Out:
# ['arabic',
#  'azerbaijani',
#  'basque',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
from nltk.corpus import names
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
names.words('male.txt')
# Out:
# ['Aamir',
#  'Aaron',
#  'Abbey',
#  'Abbie',
#  'Abbot',
#  'Abbott',
#  'Abby',
#  'Abdel',
#  'Abdul',
#  'Abdulkarim',
#  'Abdullah',
#  'Abe',
#  'Abel',
#  'Abelard',
#  'Abner',
#  'Abraham',
#  'Abram',
#  'Ace',
#  'Adair',
#  'Adam',
#  'Adams',
#  'Addie',
#  'Adger',
#  'Aditya',
#  'Adlai',
#  'Adnan',
#  'Adolf',
#  'Adolfo',
#  'Adolph',
#  'Adolphe',
#  'Adolpho',
#  'Adolphus',
#  'Adrian',
#  'Adrick',
#  'Adrien',
#  'Agamemnon',
#  'Aguinaldo',
#  'Aguste',
#  'Agustin',
#  'Aharon',
#  'Ahmad',
#  'Ahmed',
#  'Ahmet',
#  'Ajai',
#  'Ajay',
#  'Al',
#  'Alaa',
#  'Alain',
#  'Alan',
#  'Alasdair',
#  'Alastair',
#  'Albatros',
#  'Albert',
#  'Alberto',
#  'Albrecht',
#  'Alden',
#  'Aldis',
#  'Aldo',
#  'Aldric',
#  'Aldrich',
#  'Aldus',
#  'Aldwin',
#  'Alec',
#  'Aleck',
#  'Alejandro',
#  'Aleks',
#  'Aleksandrs',
#  'Alessandro',
#  'Alex',
#  'Alexander',
#  'Alexei',
#  'Alexis',
#  'Alf',
#  'Alfie',
#  'Alfonse',
#  'Alfonso',
#  'Alfonzo',
# ...

# %%
names.words('female.txt')
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...

# %% [markdown]
# #### Corpus vs lexicon
#
# Corpus is large collection of text data (written or spoken) in particular language. A corpus may include additional information about the words like their POS tags or parse tree of sentences etc.
#
# Lexicon is the entire set of a language’s lexemes. Many lexicons contains a core token (lexeme), its Noun form, adjective form, related verb, related adverb etc., its Synonym, antonym etc.

# %% [markdown]
# ##### opinion_lexicon
# A list of positive and negative opinion words or sentiment words for English.

# %%
from nltk.corpus import opinion_lexicon
opinion_lexicon.words()[:10]
# Out:
# ['2-faced',
#  '2-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted']

# %%
opinion_lexicon.negative()[:5]
# Out:
# ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable']

# %% [markdown]
# ##### product_reviews_1 and product_reviews_2
# These two datasets respectively contain annotated customer reviews of 5 and 9 products from amazon.com.

# %%
from nltk.corpus import product_reviews_1
camera_reviews = product_reviews_1.reviews('Canon_G3.txt')
review = camera_reviews[0]
review.sents()[0]
# Out:
# ['i',
#  'recently',
#  'purchased',
#  'the',
#  'canon',
#  'powershot',
#  'g3',
#  'and',
#  'am',
#  'extremely',
#  'satisfied',
#  'with',
#  'the',
#  'purchase',
#  '.']

# %%
review.features()
# Out:
# [('canon powershot g3', '+3'),
#  ('use', '+2'),
#  ('picture', '+2'),
#  ('picture quality', '+1'),
#  ('picture quality', '+1'),
#  ('camera', '+2'),
#  ('use', '+2'),
#  ('feature', '+1'),
#  ('picture quality', '+3'),
#  ('use', '+1'),
#  ('option', '+1')]

# %% [markdown]
# ### Simple NLP Tasks in NLTK:   Tokenization

# %%
# Tokenization
from nltk import word_tokenize, sent_tokenize
sent = "I will walk 500 miles and I would walk 500 more, just to be the man who walks a thousand miles to fall down at your door!"
print(word_tokenize(sent))
print(sent_tokenize(sent))
# Out:
# ['I', 'will', 'walk', '500', 'miles', 'and', 'I', 'would', 'walk', '500', 'more', ',', 'just', 'to', 'be', 'the', 'man', 'who', 'walks', 'a', 'thousand', 'miles', 'to', 'fall', 'down', 'at', 'your', 'door', '!']
# ['I will walk 500 miles and I would walk 500 more, just to be the man who walks a thousand miles to fall down at your door!']

# %% [markdown]
# ### Stopwords removal

# %%
#Stopwords removal
from nltk.corpus import stopwords        # the corpus module is an extremely useful one. 
sent = "I will walk 500 miles and I would walk 500 more, just to be the man who walks a thousand miles to fall down at your door!"                                         
stop_words = stopwords.words('english')  # this is the full list of all stop-words stored in nltk
token = nltk.word_tokenize(sent)
cleaned_token = []
for word in token:
    if word not in stop_words:
        cleaned_token.append(word)
print("This is the unclean version:", token)
print("This is the cleaned version:", cleaned_token)
# Out:
# This is the unclean version: ['I', 'will', 'walk', '500', 'miles', 'and', 'I', 'would', 'walk', '500', 'more', ',', 'just', 'to', 'be', 'the', 'man', 'who', 'walks', 'a', 'thousand', 'miles', 'to', 'fall', 'down', 'at', 'your', 'door', '!']
# This is the cleaned version: ['I', 'walk', '500', 'miles', 'I', 'would', 'walk', '500', ',', 'man', 'walks', 'thousand', 'miles', 'fall', 'door', '!']

# %% [markdown]
# ###  Stemming and Lemmatization
#
# Stemming is the process of removing the suffixes from a word.
# Lemmatization converts a word into its base form (lemma).
#
# The difference between stemming and lemmatization is that lemmatization involves morphological analysis and considers the context.

# %% [markdown]
# #### Stemming

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print(stemmer.stem("feet"))
# Out:
# feet

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = ['play', 'playing', 'plays', 'played','playfullness', 'playful']
stemmed = [stemmer.stem(word) for word in words]
print(stemmed)
# Out:
# ['play', 'play', 'play', 'play', 'playful', 'play']

# %%
sent2 = "I played the play playfully as the players were playing in the play with playfullness"
token = nltk.word_tokenize(sent2)
stemmed = ""
for word in token:
    stemmed += stemmer.stem(word) + " "
print(stemmed)
# Out:
# i play the play play as the player were play in the play with playful

# %% [markdown]
# You can also train your own using unsupervised clustering or supervised classification ML models.
#
# #### Lemmatization

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("feet"))
# Out:
# foot

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

sent = "I have two hands a two feet"
tokens = nltk.word_tokenize(sent)
print('Tokens:', tokens)

lemmed = [WordNetLemmatizer().lemmatize(t) for  t in tokens] 
print('Lemmas:', lemmed)
# Out:
# Tokens: ['I', 'have', 'two', 'hands', 'a', 'two', 'feet']
# Lemmas: ['I', 'have', 'two', 'hand', 'a', 'two', 'foot']

# %% [markdown]
# ### Part of Speech Tagging

# %%
# POS tagging
from nltk import pos_tag 
from nltk.corpus import stopwords 

stop_words = stopwords.words('english')

sentence = "The pos_tag() method takes in a list of tokenized words, and tags each of them with a corresponding Parts of Speech"
tokens = nltk.word_tokenize(sentence)

cleaned_token = []
for word in tokens:
    if word not in stop_words:
        cleaned_token.append(word)
tagged = pos_tag(cleaned_token)                 
print(tagged)
# Out:
# [('The', 'DT'), ('pos_tag', 'NN'), ('(', '('), (')', ')'), ('method', 'NN'), ('takes', 'VBZ'), ('list', 'NN'), ('tokenized', 'JJ'), ('words', 'NNS'), (',', ','), ('tags', 'NNS'), ('corresponding', 'VBG'), ('Parts', 'NNS'), ('Speech', 'NN')]

# %% [markdown]
# The pos_tag() method takes in a list of tokenized words, and tags each of them with a corresponding Parts of Speech identifier into tuples. For example, VB refers to ‘verb’, NNS refers to ‘plural nouns’, DT refers to a ‘determiner’.
#
# ### Named Entity Recognition :
#
# NER is the NLP task of locating and classifying named entities into pre-defined categories such as the names of persons, organizations, locations, expressions of times, quantities, monetary values, percentages, etc. It helps answer questions like this:
# - Which companies were mentioned in the report?
# - Does the tweet speak about a specific person?
# - What places, which companies are mentioned in the news article?
# - Which product is being spoken about?

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities
# Out:
# Tree('S', [('I', 'PRP'), ('played', 'VBD'), ('play', 'NN'), ('playfully', 'RB'), ('players', 'NNS'), ('playing', 'VBG'), ('play', 'NN'), ('playfullness', 'NN')])

# %% [markdown]
# ### Collocations and Bigrams

# %%
import nltk
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()
fourgram_measures = nltk.collocations.QuadgramAssocMeasures()
finder = BigramCollocationFinder.from_words(nltk.corpus.genesis.words('english-web.txt'))
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('Allon', 'Bacuth'),
#  ('Ashteroth', 'Karnaim'),
#  ('Ben', 'Ammi'),
#  ('En', 'Mishpat'),
#  ('Jegar', 'Sahadutha'),
#  ('Salt', 'Sea'),
#  ('Whoever', 'sheds'),
#  ('appoint', 'overseers'),
#  ('aromatic', 'resin'),
#  ('cutting', 'instrument')]

# %%
#While these words are highly collocated, the expressions are also very infrequent. T
#herefore it is useful to apply filters, such as ignoring all bigrams which occur less than three times in the corpus:

finder.apply_freq_filter(3)
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('Beer', 'Lahai'),
#  ('Lahai', 'Roi'),
#  ('gray', 'hairs'),
#  ('ewe', 'lambs'),
#  ('Most', 'High'),
#  ('many', 'colors'),
#  ('burnt', 'offering'),
#  ('Paddan', 'Aram'),
#  ('east', 'wind'),
#  ('living', 'creature')]

# %% [markdown]
# ### WordNet Corpus Reader
# WordNet is An NLTK interface for WordNet. WordNet is a lexical database of English. WordNet uses Synsets to store words. A synset is a set of synonyms that share a common meaning. Using synsets, it helps find conceptual relationships between words such.

# %%
from nltk.corpus import wordnet as wn
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
wn.synsets('dog', pos=wn.VERB)
# Out:
# [Synset('chase.v.01')]

# %% [markdown]
# ##### The WordNet corpus reader gives access to the Open Multilingual WordNet, using ISO-639 language codes. These languages are not loaded by default, but only lazily, when needed.

# %%
sorted(wn.langs())
# Out:
# ['als',
#  'arb',
#  'bul',
#  'cat',
#  'cmn',
#  'dan',
#  'ell',
#  'eng',
#  'eus',
#  'fin',
#  'fra',
#  'glg',
#  'heb',
#  'hrv',
#  'ind',
#  'isl',
#  'ita',
#  'ita_iwn',
#  'jpn',
#  'lit',
#  'nld',
#  'nno',
#  'nob',
#  'pol',
#  'por',
#  'ron',
#  'slk',
#  'slv',
#  'spa',
#  'swe',
#  'tha',
#  'zsm']

# %% [markdown]
# #### nltk moview reviews

# %%
import nltk
import string
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import movie_reviews
movie_reviews.fileids()[:5]
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt']

# %%
movie_reviews.fileids()[-5:]
# Out:
# ['pos/cv995_21821.txt',
#  'pos/cv996_11592.txt',
#  'pos/cv997_5046.txt',
#  'pos/cv998_14111.txt',
#  'pos/cv999_13106.txt']

# %%
negative_fileids = movie_reviews.fileids('neg')
positive_fileids = movie_reviews.fileids('pos')

# %%
movie_reviews.words(fileids=positive_fileids[0])
# Out:
# ['films', 'adapted', 'from', 'comic', 'books', 'have', ...]

# %% [markdown]
# #### Building a classifier for movie reviews using NLTK Naive Bayes Classifier

# %%
import nltk
import string
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import movie_reviews

def feature_extraction(words):
    stopwordsandpunct = nltk.corpus.stopwords.words("english") + list(string.punctuation)
    return { word:'present' for word in words if not word in stopwordsandpunct}

negative_features = [(feature_extraction(movie_reviews.words(fileids=[f])), 'neg') for f in negative_fileids]
positive_features = [(feature_extraction(movie_reviews.words(fileids=[f])), 'pos') for f in positive_fileids]

# %%
negative_features[:10]
# Out:
# [({'plot': 'present',
#    'two': 'present',
#    'teen': 'present',
#    'couples': 'present',
#    'go': 'present',
#    'church': 'present',
#    'party': 'present',
#    'drink': 'present',
#    'drive': 'present',
#    'get': 'present',
#    'accident': 'present',
#    'one': 'present',
#    'guys': 'present',
#    'dies': 'present',
#    'girlfriend': 'present',
#    'continues': 'present',
#    'see': 'present',
#    'life': 'present',
#    'nightmares': 'present',
#    'deal': 'present',
#    'watch': 'present',
#    'movie': 'present',
#    'sorta': 'present',
#    'find': 'present',
#    'critique': 'present',
#    'mind': 'present',
#    'fuck': 'present',
#    'generation': 'present',
#    'touches': 'present',
#    'cool': 'present',
#    'idea': 'present',
#    'presents': 'present',
#    'bad': 'present',
#    'package': 'present',
#    'makes': 'present',
#    'review': 'present',
#    'even': 'present',
#    'harder': 'present',
#    'write': 'present',
# ...

# %%
positive_features[:10]
# Out:
# [({'films': 'present',
#    'adapted': 'present',
#    'comic': 'present',
#    'books': 'present',
#    'plenty': 'present',
#    'success': 'present',
#    'whether': 'present',
#    'superheroes': 'present',
#    'batman': 'present',
#    'superman': 'present',
#    'spawn': 'present',
#    'geared': 'present',
#    'toward': 'present',
#    'kids': 'present',
#    'casper': 'present',
#    'arthouse': 'present',
#    'crowd': 'present',
#    'ghost': 'present',
#    'world': 'present',
#    'never': 'present',
#    'really': 'present',
#    'book': 'present',
#    'like': 'present',
#    'hell': 'present',
#    'starters': 'present',
#    'created': 'present',
#    'alan': 'present',
#    'moore': 'present',
#    'eddie': 'present',
#    'campbell': 'present',
#    'brought': 'present',
#    'medium': 'present',
#    'whole': 'present',
#    'new': 'present',
#    'level': 'present',
#    'mid': 'present',
#    '80s': 'present',
#    '12': 'present',
#    'part': 'present',
# ...

# %%
from nltk.classify import NaiveBayesClassifier #load the buildin classifier
clf = NaiveBayesClassifier.train(positive_features[:500]+negative_features[:500])  
#train it on 50% of records in positive and negative reviews
nltk.classify.util.accuracy(clf, positive_features[500:]+negative_features[500:])*100  #test it on remaining 50% records
# Out:
# 79.60000000000001

# %%
clf.show_most_informative_features()
# Out:
# Most Informative Features
#               whatsoever = 1                 neg : pos    =     14.3 : 1.0
#                    inept = 1                 neg : pos    =     13.7 : 1.0
#                ludicrous = 1                 neg : pos    =     11.7 : 1.0
#               nomination = 1                 pos : neg    =     11.7 : 1.0
#                stupidity = 1                 neg : pos    =     11.7 : 1.0
#                    views = 1                 pos : neg    =     10.3 : 1.0
#               vulnerable = 1                 pos : neg    =     10.3 : 1.0
#                abilities = 1                 neg : pos    =      9.7 : 1.0
#              exceptional = 1                 pos : neg    =      9.7 : 1.0
#                fictional = 1                 pos : neg    =      9.7 : 1.0

# %% [markdown]
# ## SpaCy

# %% [markdown]
# Spacy is an free, opensource and industrial-strength library for NLP in Python. It provides a huge ecosystem of plugins, and components, and enables you to build custom components and workflows. Features of SpaCy are :
#
# - Support for 72+ languages
# - 80 trained pipelines for 24 languages
# - Multi-task learning with pretrained transformers like BERT
# - Pretrained word vectors
# - State-of-the-art speed
# - Production-ready training system
# - Linguistically-motivated tokenization
# - Components for named entity recognition, part-of-speech tagging, dependency parsing, sentence segmentation, text classification, lemmatization, morphological analysis, entity linking and more
# - Easily extensible with custom components and attributes
# - Support for custom models in PyTorch, TensorFlow and other frameworks
# - Built in visualizers for syntax and NER
# - Easy model packaging, deployment and workflow management
# - Robust, rigorously evaluated accuracy
#
# ### Download and Install (https://spacy.io/usage)
#
# Using pip:
# <code>
# pip install -U pip setuptools wheel
# pip install -U spacy
# </code>
#
# Using conda:
# <code>conda install -c conda-forge spacy</code>
#
#
# After installing spacy, we need to download the suitable NLP pipeline of a language we usually work with (English in our case):
#
# <code>python -m spacy download en_core_web_sm</code>
#
# spaCy’s trained pipelines can be installed as Python packages. Trained pipelines can be installed from a download URL or a local directory, manually or via pip. Their data can be located anywhere on your file system.
#
# ### Functionality provided by SpaCy:
#
# |NAME|	DESCRIPTION|
# |:-|:-|
# |Tokenization|	Segmenting text into words, punctuations marks etc.|
# |Part-of-speech (POS) Tagging|	Assigning word types to tokens, like verb or noun.|
# |Dependency Parsing	|Assigning syntactic dependency labels, describing the relations between individual tokens, like subject or object.|
# |Lemmatization|	Assigning the base forms of words. For example, the lemma of “was” is “be”, and the lemma of “rats” is “rat”.|
# |Sentence Boundary Detection (SBD)	|Finding and segmenting individual sentences.|
# |Named Entity Recognition (NER)	|Labelling named “real-world” objects, like persons, companies or locations.|
# |Entity Linking (EL)|	Disambiguating textual entities to unique identifiers in a knowledge base.|
# |Similarity|	Comparing words, text spans and documents and how similar they are to each other.|
# |Text Classification|	Assigning categories or labels to a whole document, or parts of a document.|
# |Rule-based Matching|	Finding sequences of tokens based on their texts and linguistic annotations, similar to regular expressions.|
# |Training|	Updating and improving a statistical model’s predictions.|
# Serialization|	Saving objects to files or byte strings.|
#
#
# ### Pretrained Pipelines / Statistical models
#
# Many features of spacy require us to load a trained pipeline. A trained pipeline can consist of multiple components that use a statistical model trained on labeled data. spaCy pipelines can be installed as individual Python modules. The pipeline packages  differ in size, speed, memory usage, accuracy and the data they include. The package you choose depends on your use case and the texts you’re working with. For a general-purpose use case, the small, default packages are always a good start. They typically include the following components:
#
#     - Binary weights for the part-of-speech tagger, dependency parser and named entity recognizer to predict those annotations in context.
#     - Lexical entries in the vocabulary, i.e. words and their context-independent attributes like the shape or spelling.
#     - Data files like lemmatization rules and lookup tables.
#     - Word vectors, i.e. multi-dimensional meaning representations of words that let you determine how similar they are to each other.
#     - Configuration options, like the language and processing pipeline settings and model implementations to use, to put spaCy in the correct state when you load the pipeline.
#
#
# 1. Once you’ve downloaded and installed a trained pipeline, you can load it via spacy.load. This will return a <b>Language </b>object containing all components and data needed to process text. We usually call it <b>nlp</b>. Calling the nlp object on a string of text will return a processed <b>Doc</b> object.
#
# 2. A Doc consists of individual tokens, and we can iterate over them.
#
# 3. During further processing, spaCy first tokenizes the text, i.e. segments it into words, punctuation and so on. This is done by applying rules specific to each language. For example, punctuation at the end of a sentence should be split off – whereas “U.K.” should remain one token. Linguistic annotations are available as <b>Token</b> attributes.
#
# 4. Part-of-speech tagging, identifying word dependencies, Named entity recognition (these tasks need a pretrained pipeline and a model). Named entities are available as the ents property of a Doc
#
# ### The Processing Pipelines
# When you call <b>nlp</b> on a text, spaCy first tokenizes the text to produce a <b>Doc</b> object. The Doc is then processed in several different steps – which is referred to as the <b>processing pipeline</b>. The pipeline used by the trained pipelines typically include a <b>tagger, a lemmatizer, a parser and an entity recognizer</b>. Each pipeline component returns the processed Doc, which is then passed on to the next component.
#
# <img src = 'pipeline.svg'>
# <center> Source: https://spacy.io/usage/spacy-101 </center>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "Apple is looking at buying U.K. startup for $1 billion"

doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP dobj X.X. False False
# startup startup NOUN NN dep xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("This is a sentence.")
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="14e7d47669ec49c6841fc8f8083da6bb-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# ## ChatGPT : A Large Language Model and a Generative Pre-trained Transformer (GPT)
#
# ### What is language modelling?
#
# - Language modeling is the task of predicting the next word or character in a document.
#
# <img src = 'suggest-min.png' width = 400 height = 400>
# <center> Source:https://lena-voita.github.io/nlp_course/language_modeling.html </center>
#
# - A language model is a machine learning model that has been trained to learn the nuances of a language.  It can be used for a number of NLP tasks like text summarization, question answering, semantic search, dialog systems.
#
# - Some language models : GPT3 (Of course!!!), Megatron-LM, BERT
#
# To be Contd..
